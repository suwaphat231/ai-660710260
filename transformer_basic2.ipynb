# %%
# !pip install -U pip transformers
# Out:
# Requirement already satisfied: pip in /usr/local/lib/python3.12/dist-packages (24.1.2)
# Collecting pip
#   Downloading pip-25.2-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (4.56.2)
# Collecting transformers
#   Downloading transformers-4.57.0-py3-none-any.whl.metadata (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.4/41.4 kB 2.5 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers) (3.19.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.35.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers) (2.32.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.6.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (2025.3.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (1.1.10)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2025.8.3)
# Downloading pip-25.2-py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 33.9 MB/s eta 0:00:00
# Downloading transformers-4.57.0-py3-none-any.whl (12.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 69.8 MB/s eta 0:00:00
# Installing collected packages: pip, transformers
#   Attempting uninstall: pip
#     Found existing installation: pip 24.1.2
#     Uninstalling pip-24.1.2:
#       Successfully uninstalled pip-24.1.2
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.56.2
#     Uninstalling transformers-4.56.2:
#       Successfully uninstalled transformers-4.56.2
# Successfully installed pip-25.2 transformers-4.57.0

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM, pipeline

# %%
checkpoint = 'facebook/nllb-200-distilled-600M'
tokenizer = AutoTokenizer.from_pretrained(checkpoint)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/564 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/4.85M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.3M [00:00<?, ?B/s]
# special_tokens_map.json: 0.00B [00:00, ?B/s]

# %%
print(f"{len(tokenizer.vocab)}\n")

tokenizer.vocab
# Out:
# 256204
# {'▁ক্ল': 56105,
#  '▁સંભવિત': 167044,
#  '▁ango': 183196,
#  '▁Edhe': 70489,
#  'oping': 240972,
#  '▁ēnei': 142388,
#  '▁DJ': 81645,
#  'idiwa': 215379,
#  '▁asoc': 128385,
#  'ལྷོད་': 180316,
#  '▁sɛbɛnnen': 205688,
#  'чва': 65434,
#  '▁λεπτό': 209107,
#  '▁Ақмола': 179294,
#  '▁riċerka': 230518,
#  '▁kararag': 227776,
#  '▁ajándék': 242864,
#  '▁محت': 109645,
#  '▁كېس': 117573,
#  'دهای': 100885,
#  '▁espé': 146245,
#  'idheann': 183740,
#  '▁llamp': 201869,
#  'Ap': 59779,
#  'ってない': 149925,
#  '▁విశ్': 125327,
#  '▁hádia': 79123,
#  '▁oly': 131507,
#  '▁meħuda': 224933,
#  'ertu': 37604,
#  '▁ընտր': 62197,
#  '▁podo': 92714,
#  '▁jet': 9399,
#  '▁brag': 222997,
#  'hever': 211578,
#  'gawi': 214481,
#  '▁masan': 203156,
#  '▁주를': 223889,
#  'íte': 16024,
#  '▁fonds': 119363,
#  '▁ಗೊತ್ತಿಲ್ಲ': 166822,
#  '▁бары': 15392,
#  '▁рӯзи': 94120,
#  '▁колдонуу': 209276,
#  '▁Verwendung': 176044,
#  '▁ponisa': 185378,
#  '▁selge': 126580,
#  '▁daba': 74465,
#  '▁фа': 11238,
#  'ctieve': 243975,
#  '▁пови': 40887,
#  '▁компании': 121289,
#  '公表': 139641,
#  '▁바꿔': 166986,
#  '▁എന്നോട്': 219403,
#  '▁isklju': 177576,
#  'obu': 10637,
#  'asok': 147849,
#  'bahn': 236699,
#  '徙': 254076,
#  '▁taq': 15689,
#  '▁IPO': 245751,
#  '▁jera': 121473,
#  '▁ɓee': 226168,
#  'াড়া': 110635,
#  'дог': 36723,
#  '▁урь': 170720,
#  '▁satisfè': 221458,
#  '▁доларів': 126384,
#  '▁bint': 197894,
#  'unty': 58882,
#  '▁mon': 1724,
#  '30%': 180378,
#  '▁apak': 46804,
#  '▁żyć': 229918,
#  '▁usada': 194123,
#  '▁aũme': 125149,
#  '▁սիր': 36395,
#  'וריה': 78097,
#  'lave': 123451,
#  '▁băr': 113798,
#  '▁Rem': 34600,
#  '▁ਆਉਂਦਾ': 179386,
#  '▁ċ': 16609,
#  '▁בנוסף': 179560,
#  '▁tunge': 162284,
#  '▁tharra': 175653,
#  '▁この場合': 232800,
#  '口座': 190892,
#  '▁айтпа': 237937,
#  '▁45,': 161651,
#  '▁mg': 6098,
#  '▁nrụ': 143299,
#  '▁algumas': 121488,
#  'आप': 72180,
#  'ရွ': 94101,
#  '▁suerte': 134714,
#  'ਉਂ': 16029,
#  '▁vnú': 60578,
#  '▁larta': 212725,
#  'வருக்கும்': 148439,
#  '學家': 243692,
#  '▁ଛୋଟ': 115065,
#  '▁ኰ': 64609,
#  '▁सबैलाई': 170678,
#  '崎': 254345,
#  'yeyi': 70486,
#  '▁jobbe': 127471,
#  '▁Ales': 228956,
#  'hoặc': 246506,
#  '過ぎ': 43367,
#  'に適用': 224237,
#  '▁ayun': 138953,
#  'sili': 50721,
#  '▁mukam': 155239,
#  '▁కళా': 177188,
#  'ekenne': 220689,
#  '必ずしも': 149182,
#  'urende': 78928,
#  'چند': 186238,
#  '▁fungsi': 55079,
#  'ಂತೆ': 20507,
#  'ံုး': 68124,
#  'བདེན་དཔང་': 182167,
#  '▁nĩtwaĩle': 231848,
#  '▁unya': 96906,
#  '▁större': 136013,
#  'ниҳо': 145396,
#  '▁টেলি': 220978,
#  '▁dèanamh': 89686,
#  '▁आधी': 84356,
#  '▁trabal': 14064,
#  'ције': 13761,
#  '▁בתור': 209757,
#  'embeka': 87030,
#  '잎': 253872,
#  'if': 4106,
#  '塔': 252126,
#  '▁баъд': 152404,
#  '▁jobbet': 137242,
#  '▁ଘଟଣା': 81061,
#  '▁prī': 186661,
#  '▁མཱ': 247814,
#  '▁jix': 116275,
#  '▁engtin': 145586,
#  '▁Дж': 38012,
#  'నాలు': 87388,
#  'qija': 205066,
#  '▁Perëndisë': 71917,
#  '▁까지': 95415,
#  '▁ব্যাখ্যা': 196482,
#  '▁тураһында': 33384,
#  '▁bulmak': 201510,
#  '▁Ọló': 17264,
#  '▁Mop': 61855,
#  '▁yɛavi': 157921,
#  'بخت': 143514,
#  '▁گؤرد': 110727,
#  '▁Clarke': 224328,
#  '▁мое': 161007,
#  '▁23,': 58714,
#  'bikku': 218326,
#  '▁বো': 50372,
#  '▁မလို': 242234,
#  '▁Arag': 151283,
#  '▁сәт': 174339,
#  '▁NZ': 128316,
#  '▁እንድ': 68967,
#  '▁고': 4345,
#  '▁Benn': 157177,
#  '▁ලැබෙන': 224632,
#  '?..': 82167,
#  '▁kɔcdït': 216785,
#  '胚': 255323,
#  'м': 248118,
#  '▁адна': 95940,
#  '▁alɔ': 35038,
#  'tosna': 227247,
#  'anyina': 167787,
#  '▁ମାନେ': 112985,
#  '▁првиот': 110457,
#  '▁caya': 106240,
#  '▁கிர': 102237,
#  '▁Jest': 24657,
#  'ítva': 185737,
#  '▁ਪਿੱਛ': 176477,
#  '▁dese': 31037,
#  '▁yĩngr': 242450,
#  'ཕྲན་': 245004,
#  '▁mevcut': 140778,
#  '▁contexte': 246826,
#  'ebo': 51845,
#  '▁пун': 61426,
#  'ક્': 4070,
#  '글': 250636,
#  '▁sret': 149053,
#  'اتل': 200238,
#  '▁ഒന്ന്': 125529,
#  '▁تەمەن': 168943,
#  '▁интересно': 214172,
#  '▁purin': 121753,
#  '▁tiek': 12273,
#  '▁хуп': 230599,
#  'ખ્': 224536,
#  '▁વૃદ્ધિ': 228076,
#  'вості': 159219,
#  'onko': 32499,
#  '新聞': 82309,
#  'гата': 62974,
#  '▁کتنی': 182044,
#  'พบ': 62070,
#  '▁ଆଧାର': 154741,
#  '▁reer': 48577,
#  '▁adgang': 70088,
#  '▁šesť': 214984,
#  '▁obulagirizi': 247593,
#  'uhl': 219432,
#  '▁wij': 22648,
#  '▁iwo': 24732,
#  '▁ስለሆነ': 111309,
#  '▁သူတို႔': 162385,
#  '▁હેઠ': 112976,
#  'зон': 82117,
#  '▁ኻብ': 70335,
#  'ھن': 8587,
#  '▁wodo': 155088,
#  '▁ئانا': 141686,
#  '្រៀន': 183075,
#  '誇りに': 173773,
#  '辩': 253774,
#  'ခံစား': 122531,
#  '▁ùn': 35025,
#  'ọtara': 102844,
#  '▁무시': 91046,
#  'ビル': 103442,
#  '▁apresent': 102030,
#  '▁現実': 229905,
#  '▁кәңәш': 173327,
#  '▁umKristu': 207855,
#  'amaso': 219467,
#  '▁համալս': 224793,
#  'dʋʋ': 65774,
#  '▁मैन': 233638,
#  '▁mengucapkan': 219567,
#  '▁Protest': 98366,
#  '▁මුලින්ම': 211781,
#  'mind': 155871,
#  '사들이': 222082,
#  '▁Fisch': 132853,
#  '▁агач': 194004,
#  '▁dipego': 237444,
#  '▁orðum': 205775,
#  '▁kapan': 37694,
#  '▁joan': 45682,
#  'yndzy': 202107,
#  '▁મિન': 157367,
#  'applikant': 156067,
#  '▁bawat': 46694,
#  'opita': 74008,
#  'եան': 58253,
#  'til': 2982,
#  '絆': 254044,
#  '▁유지': 30225,
#  '▁raksasa': 239542,
#  '▁بارها': 195995,
#  '▁basakoli': 201177,
#  'ຽດ': 67169,
#  'gging': 175980,
#  'stol': 66980,
#  '▁matematika': 88318,
#  '▁सेवा': 19458,
#  '▁Мі': 51131,
#  '▁matshalatshala': 111724,
#  '▁humeleleke': 206843,
#  '▁מער': 23458,
#  '▁ወድ': 235481,
#  '两': 251444,
#  'atuan': 83840,
#  'گىنى': 80928,
#  '▁banjye': 169340,
#  '▁Ку': 7805,
#  'われわれの': 104897,
#  'Va': 18012,
#  '▁ئەلۋەتتە': 56564,
#  'blog': 114552,
#  'ከረ': 236503,
#  '▁Alebo': 181013,
#  '▁xí': 206573,
#  'رىتى': 119976,
#  '▁împ': 150680,
#  '▁vinyake': 148212,
#  'sul': 31728,
#  '📌': 255320,
#  '▁Wabula': 188852,
#  '▁Cukup': 212308,
#  '▁здійс': 82576,
#  '2014': 85436,
#  'layika': 204995,
#  '▁dest': 6485,
#  'ekula': 203949,
#  '▁Xaqa': 224271,
#  '▁majaw': 21212,
#  'mma': 84639,
#  '▁करीं': 163432,
#  'চৰ': 75219,
#  '▁ئىچى': 39913,
#  '▁ibukota': 247969,
#  '▁τμή': 149775,
#  '▁αγάπη': 148067,
#  '▁αντικ': 109183,
#  '倦': 255493,
#  'ɛlim': 72974,
#  '▁ਕਿਤੇ': 195739,
#  'šo': 3699,
#  'تیار': 43408,
#  '博': 251313,
#  'ството': 19853,
#  '▁အဆင့်': 205917,
#  '▁xas': 206736,
#  '▁asto': 182914,
#  '하시': 16375,
#  'ದೆ': 6273,
#  '▁cud': 37813,
#  '▁najbolji': 146028,
#  '▁Opra': 206757,
#  '▁Temos': 74717,
#  '▁fazem': 189644,
#  '▁Vous': 12494,
#  'aro': 1142,
#  'iva': 52778,
#  'ğımız': 203455,
#  '▁Ủ': 174778,
#  'дорхой': 93345,
#  '▁telekommun': 219989,
#  '▁게임을': 64502,
#  'urati': 128010,
#  'ৰু': 5890,
#  '▁4:4;': 170637,
#  'premessa': 224181,
#  '▁yindulaka': 216677,
#  '▁normas': 62954,
#  'స్తాడు': 110169,
#  '▁ozi': 15387,
#  '▁دەلى': 121515,
#  'athana': 28793,
#  'imhe': 29774,
#  '▁asɔfo': 174083,
#  '೩': 254500,
#  '▁смислу': 231476,
#  '▁sumala': 93449,
#  '▁oziroma': 141349,
#  '▁ሲያ': 115096,
#  '▁fwyta': 226489,
#  '▁ære': 192762,
#  'рыі': 208395,
#  '▁даяр': 56359,
#  '▁ধন্যবাদ': 102203,
#  '▁ਪ੍ਰਸ': 142561,
#  'asipxam': 158306,
#  '▁siseri': 241937,
#  'rov': 11922,
#  'લ': 248731,
#  '▁progetto': 127189,
#  'ори': 76724,
#  '▁annu': 52841,
#  '▁kutula': 87451,
#  'opera': 14892,
#  '▁σημαν': 81256,
#  'onyeni': 218205,
#  '▁نکرد': 67462,
#  'なさ': 172465,
#  '▁bakap': 226791,
#  '▁آئے': 54728,
#  'arma': 43230,
#  '▁դուր': 67243,
#  '▁Kina': 30707,
#  '▁ауы': 28140,
#  '▁چونکە': 54719,
#  'чылары': 195377,
#  '▁dↄ': 214063,
#  '▁ઘો': 242366,
#  '▁exclu': 146132,
#  '▁nekom': 154964,
#  'қтау': 30048,
#  'oraan': 118542,
#  'ανά': 81428,
#  'રને': 58169,
#  '▁nyelv': 154748,
#  'ואר': 98732,
#  '▁सुधार': 45363,
#  '▁eneo': 94599,
#  '▁lalla': 136128,
#  '▁mwyn': 44779,
#  '身份': 203547,
#  'vival': 78143,
#  'ئەگەر': 130601,
#  '▁хори': 118268,
#  '设备': 193298,
#  '▁المتحدة': 181428,
#  'alenge': 45266,
#  '▁Lamb': 136043,
#  'sel': 12294,
#  '▁persuni': 86683,
#  '▁nyumba': 26328,
#  '▁penghasilan': 203670,
#  '▁будь': 30872,
#  'արժ': 159335,
#  '▁anisan': 128214,
#  '▁유지할': 221965,
#  'ੰਭੀਰ': 206875,
#  '▁cola': 24571,
#  '▁нашим': 104782,
#  '▁cene': 131624,
#  '▁napriek': 197942,
#  'ાયા': 124494,
#  'ંદ': 15307,
#  '▁troll': 211622,
#  'ଦ': 248899,
#  'ziva': 18079,
#  '▁तोहका': 37314,
#  'ነ': 248686,
#  '▁പത്ര': 244142,
#  '▁fase': 32384,
#  '▁நினை': 30587,
#  '▁huenda': 81049,
#  'şam': 61991,
#  '▁უფალი': 204120,
#  '▁છુ': 179425,
#  'टीक': 90703,
#  '▁anci': 52954,
#  '▁herë': 51264,
#  'ཁྱིམ་': 47335,
#  'imahsela': 225585,
#  '▁sąlyg': 138360,
#  'ngopfu': 111311,
#  '▁उपन्यास': 230356,
#  '▁rapid': 50416,
#  '▁adis': 124967,
#  'pheo': 188173,
#  '▁खि': 100322,
#  '▁tetee': 231267,
#  '▁kaja': 37648,
#  '▁लागे': 151290,
#  'apur': 229583,
#  '▁শৰীৰ': 211478,
#  '▁prolong': 172729,
#  'om': 58,
#  '卸': 255258,
#  '▁UU': 211558,
#  '▁priebehu': 166100,
#  'ാൻ': 4201,
#  'مە': 5558,
#  'ĺž': 169283,
#  '▁አንዳን': 145169,
#  'trɛ': 214191,
#  'ireachtaí': 204899,
#  '▁उनखा': 158644,
#  'بئر': 105325,
#  '心から': 157060,
#  'эў': 173845,
#  '轻': 253075,
#  'õig': 82033,
#  '▁antall': 134659,
#  '眉': 255604,
#  '监': 252521,
#  '▁nagsiring': 103318,
#  '▁მარ': 44509,
#  'ليا': 111891,
#  '▁kurioms': 226256,
#  '▁ngồi': 95171,
#  '▁ئەۋ': 96105,
#  '坦': 252094,
#  'あたり': 133346,
#  '▁hoṛ': 111963,
#  '▁ଭାରତର': 104032,
#  '▁loñoloha': 193284,
#  '▁მისი': 37881,
#  'oru': 11555,
#  '▁Baš': 156921,
#  'io': 3414,
#  '▁endzaweni': 216673,
#  '▁adires': 246982,
#  '▁vimue': 33885,
#  'ൻ': 249251,
#  '▁흩': 238715,
#  '전을': 79906,
#  'তকৈ': 90081,
#  'äp': 29944,
#  '▁dogodilo': 95289,
#  '▁Nɔhalɛ': 144507,
#  '▁тәшкил': 151101,
#  '▁mulifuchi': 126836,
#  '▁Kø': 186448,
#  '▁ую': 152578,
#  '▁Ary': 24980,
#  '▁koi': 50062,
#  '▁suspen': 118175,
#  'וכל': 45304,
#  'ador': 6286,
#  'ceku': 164599,
#  'ustatud': 75405,
#  '▁احتمال': 26085,
#  '▁२': 12642,
#  '汉': 254289,
#  '▁מל': 64912,
#  '▁pric': 188501,
#  'egay': 59411,
#  '년에': 34750,
#  'コン': 12243,
#  '▁ردا': 177098,
#  'boti': 112615,
#  '▁ওচৰ': 178693,
#  'вању': 121387,
#  '▁ria': 30751,
#  '▁സെ': 71518,
#  'മായിരിക്കും': 238706,
#  'mata': 22471,
#  'வீர்கள்': 171998,
#  '▁ṣẹda': 227714,
#  '▁nnoši': 176595,
#  '▁40,': 89371,
#  '背': 251242,
#  '▁मुस्क': 208073,
#  '▁מאכן': 192369,
#  '▁käytettä': 157147,
#  'ит': 32006,
#  '▁tayod': 177746,
#  '▁bikólo': 135317,
#  '▁nacio': 203487,
#  '▁proveni': 130147,
#  'lår': 155931,
#  '▁greu': 69595,
#  '▁alli': 49025,
#  '▁џ': 168659,
#  'čkim': 181456,
#  '▁結婚': 124123,
#  '▁fazzu': 221839,
#  'дзіць': 71909,
#  '▁choinneáil': 149975,
#  '▁འཛམ་': 93005,
#  '▁براي': 85875,
#  '▁ganjí': 151520,
#  '▁ئۆي': 72388,
#  '▁Biztos': 170486,
#  '▁gastr': 159568,
#  'ciół': 143679,
#  'engeli': 18305,
#  '▁pallabres': 163064,
#  '▁monyetla': 133777,
#  '▁लं': 45146,
#  '▁scoile': 157397,
#  '▁progetti': 145199,
#  '▁fog': 10761,
#  '▁ଉଦ୍ୟମ': 215282,
#  '▁Suks': 214978,
#  'āliem': 140098,
#  '▁aswan': 89122,
#  '▁ndiwo': 89507,
#  '▁mawazo': 163536,
#  'untas': 76152,
#  '▁zgjedh': 122137,
#  'そうした': 129938,
#  '/59/': 244444,
#  'ᱵ': 250830,
#  '▁વાત': 33265,
#  '▁rayeuk': 99135,
#  'កំណត់': 208558,
#  '▁поэтому': 145197,
#  '▁menceritakan': 223095,
#  'llata': 163804,
#  '▁Yesaia': 167888,
#  'inya': 3442,
#  '一切': 31804,
#  '▁ìjọsìn': 184277,
#  '▁kokokisa': 115699,
#  'ੜ': 249858,
#  '▁Anjeun': 25648,
#  '▁poslali': 206680,
#  'πισ': 65703,
#  '▁تک': 10942,
#  '▁прой': 169163,
#  'าค': 182010,
#  'duanya': 162360,
#  '▁विवेक': 228841,
#  'いていた': 67789,
#  'ርስዎ': 38417,
#  '状態': 29260,
#  '▁განს': 73801,
#  '▁땅의': 163337,
#  'okpɔ': 239609,
#  'BAR': 141132,
#  '▁Poste': 239488,
#  'gbɛ': 94957,
#  '▁তেওঁৰ': 34931,
#  '▁உரி': 113949,
#  '▁адпа': 208964,
#  'engnge': 163370,
#  '▁neños': 192144,
#  '▁လ': 2148,
#  '▁apas': 191383,
#  '▁өткен': 48920,
#  '▁дозволу': 237170,
#  'परी': 161514,
#  'మయ్య': 220784,
#  'čením': 243164,
#  '▁IMF': 142667,
#  '▁infra': 82951,
#  '▁смогу': 181018,
#  'റിഞ്ഞ': 232084,
#  '▁Regu': 46790,
#  'ттарында': 230850,
#  'ROM': 192081,
#  '▁fintzas': 88971,
#  'யம்': 47420,
#  '▁ათ': 113073,
#  '▁mmom': 46187,
#  'illeadh': 48184,
#  'צע': 50044,
#  'をや': 195117,
#  '▁Kampf': 208445,
#  '▁тога': 31661,
#  '▁tímto': 222454,
#  '▁जगा': 111364,
#  'efese': 165385,
#  'tować': 203951,
#  '▁بسي': 174615,
#  'ଲାଣି': 209843,
#  '▁tahẽkana': 176633,
#  'рым': 16711,
#  '▁Samuela': 225117,
#  '▁nyikiwa': 202162,
#  '▁26:1': 76389,
#  '▁yhd': 37102,
#  '▁يوقتۇر': 148368,
#  'әре': 81055,
#  '▁сотрудни': 113720,
#  '▁கலா': 237075,
#  '▁lồ': 182278,
#  '▁semetone': 48961,
#  'сати': 172483,
#  'atat': 85283,
#  '▁Saksi': 36837,
#  '▁Lun': 165704,
#  '▁alltid': 31090,
#  '▁କରନ୍ତୁ': 54855,
#  '▁جہنم': 159165,
#  'дата': 25723,
#  'ligting': 96704,
#  '▁का': 879,
#  '厳': 251616,
#  'стината': 142407,
#  'iləcək': 200292,
#  '▁narat': 210679,
#  '▁jauniešu': 216252,
#  '▁"..': 202972,
#  'chun': 90596,
#  'اکي': 127991,
#  '▁utjas': 167958,
#  '▁állás': 218934,
#  '▁kebutuhan': 66957,
#  'гаш': 15204,
#  'igna': 160778,
#  'রক': 83397,
#  '▁swim': 113602,
#  '▁ਰਾਹੀਂ': 132863,
#  'ភ្ល': 87002,
#  '▁voy': 43613,
#  'боль': 172201,
#  'приклад': 57775,
#  '▁dus': 12779,
#  '▁èèyàn': 19156,
#  '▁хеҙ': 30507,
#  '▁Departamento': 197382,
#  'udravua': 218507,
#  '▁ukxa': 229944,
#  '▁limite': 98849,
#  '▁έβ': 180769,
#  '▁주차': 180493,
#  'angisa': 134988,
#  '▁cuán': 243952,
#  '▁မြန်မာ': 218253,
#  '▁comprend': 129827,
#  '▁געה': 51814,
#  '▁нако': 141114,
#  '▁омогући': 198178,
#  '▁Icyakora': 120916,
#  '▁bisobanura': 218715,
#  'மார': 192862,
#  'itina': 168980,
#  'ght': 42377,
#  '▁μπαμπάς': 244754,
#  '协助': 121381,
#  '▁solltest': 206085,
#  '▁يرده': 124015,
#  '▁элчи': 136051,
#  '▁uvo': 90808,
#  'གནོད་': 166404,
#  'ουν': 5440,
#  '▁menampilkan': 149901,
#  '▁pendere': 140900,
#  '▁pegi': 143472,
#  'ittel': 45229,
#  'যা': 193851,
#  '▁(8)': 56543,
#  'unguka': 199821,
#  '▁گۈل': 191134,
#  '▁whakatika': 142316,
#  '▁fordi': 23636,
#  '▁म्हटलं': 197833,
#  '▁catt': 227697,
#  'ٹر': 27386,
#  'շխան': 101988,
#  '▁Ubur': 120798,
#  '▁kailangan': 41797,
#  '▁2:5,': 224735,
#  '▁ئەڭ': 40566,
#  '▁lòd': 108006,
#  'あの': 50276,
#  '▁பெற': 124648,
#  'Pang': 237055,
#  'ɐ': 254591,
#  '▁Non': 5013,
#  '▁olhar': 193910,
#  '▁گؤزونده': 195219,
#  '▁твой': 87133,
#  '▁Anka': 118750,
#  '▁používať': 132723,
#  'ത്യ': 14122,
#  '▁söýgü': 176684,
#  '▁kumaka': 50943,
#  'iril': 36343,
#  '▁सवाल': 47496,
#  '▁vágy': 242065,
#  '▁узро': 181006,
#  'ciális': 199152,
#  '▁rékko': 51475,
#  '▁Floyd': 194961,
#  '▁mayor': 20115,
#  '▁Î': 8860,
#  'ляється': 151044,
#  'とっても': 220186,
#  'ятся': 101553,
#  'porten': 167343,
#  '▁енгле': 154683,
#  'biya': 31787,
#  '▁مەۋ': 164280,
#  'აღ': 42833,
#  '▁мәр': 62553,
#  '▁Austra': 14570,
#  'чень': 33642,
#  '▁따르는': 155293,
#  'embrī': 65351,
#  'зан': 14384,
#  'forzi': 203330,
#  '!-': 196725,
#  '▁успіху': 219239,
#  '▁потпу': 68155,
#  '▁secolo': 219813,
#  'ปาก': 202708,
#  '▁हाथ': 36175,
#  '▁işler': 120115,
#  'देशे': 205857,
#  'înin': 50779,
#  'limet': 100965,
#  'リアル': 109976,
#  '▁መጀመሪያ': 145701,
#  '▁Ariko': 23603,
#  '▁द्र': 108785,
#  '▁Paige': 244513,
#  '▁ditaba': 69215,
#  '십니까': 54073,
#  '▁வைக்க': 155776,
#  '▁تظن': 194934,
#  'ေ့လာ': 92473,
#  '▁dafe': 188497,
#  'freds': 184602,
#  'ையே': 51683,
#  'erdos': 155149,
#  '▁spieg': 142302,
#  '▁kid': 14592,
#  '▁Ung': 24730,
#  'lies': 32545,
#  '▁ଏବଂ': 12528,
#  '全然': 170520,
#  '▁सदस्यों': 186327,
#  'ghiu': 68751,
#  '▁Эз': 152312,
#  'ùdadh': 114347,
#  '▁gurée': 230964,
#  '纷': 255168,
#  '▁सफेद': 193017,
#  '▁jaqgħu': 247161,
#  '▁གཏིང་': 206167,
#  '▁დაკარგ': 226076,
#  '▁відомо': 138592,
#  '▁шалт': 120176,
#  '▁upang': 12720,
#  '▁vwaya': 111481,
#  '▁soin': 179361,
#  '/15,': 129406,
#  '▁políticu': 157822,
#  '▁wama': 60754,
#  '▁కలిగించ': 238845,
#  '▁målet': 124190,
#  '레이': 21046,
#  '▁sobom': 205911,
#  '▁ஸ்': 97409,
#  'саи': 150463,
#  '▁navela': 64336,
#  '▁Ακόμα': 205776,
#  '▁بالن': 88347,
#  '▁Gan': 37361,
#  '▁ଲାଗିଛି': 236637,
#  'urus': 35007,
#  'ុណ': 36438,
#  'nīca': 229911,
#  ':': 248144,
#  '▁olonjali': 94225,
#  '▁республикалық': 80507,
#  'ැති': 96411,
#  '▁шавед': 170028,
#  'hst': 124534,
#  '▁ہاتھ': 66594,
#  'gò': 59766,
#  '▁Indiana': 112851,
#  'ovšet': 175343,
#  'штанд': 212004,
#  '▁méta': 205750,
#  'ວັນທີ': 122530,
#  'lerden': 43823,
#  'แก่พวกเขา': 202167,
#  'chinan': 220537,
#  '▁Â': 24190,
#  '▁Uga': 171382,
#  '▁یہی': 59924,
#  '▁Nayaw': 208183,
#  'したが': 34205,
#  '▁வெளியே': 109707,
#  '▁jāiz': 106455,
#  '▁pasaulio': 73125,
#  'terminu': 245095,
#  'giai': 229735,
#  'ਸਲ': 117184,
#  '▁Connect': 208093,
#  'を指': 197071,
#  '容疑': 160839,
#  '▁ویتامین': 166735,
#  'єш': 123030,
#  '▁taz': 121012,
#  '▁yeyote': 101460,
#  'ping': 25989,
#  '▁ца': 19858,
#  'Str': 134293,
#  'itao': 241679,
#  '▁ahunda': 127847,
#  'joale': 218180,
#  'tim': 2391,
#  '▁зане': 163431,
#  '▁ວິດ': 220336,
#  '▁நேரம்': 79458,
#  '\'".': 79833,
#  'garia': 94962,
#  'ánd': 22340,
#  '▁ette': 30818,
#  'yoan': 131503,
#  'міз': 22750,
#  'elewa': 50105,
#  '▁ақпаратты': 151625,
#  'ಣ್ಣ': 30648,
#  'ox': 8279,
#  '▁ref': 10267,
#  '▁절망': 208662,
#  '▁performan': 63012,
#  'estos': 52149,
#  '▁ahoɔden': 114605,
#  '▁Suba': 112695,
#  '▁Μπορείς': 131539,
#  'yezett': 178401,
#  '▁දෙවි': 92435,
#  '数週間': 242928,
#  '▁مؤمنان': 214740,
#  'ape': 4149,
#  '▁Lond': 11766,
#  '▁سچے': 208933,
#  '▁1700': 159687,
#  'enda': 1171,
#  '▁моз': 79666,
#  'हरूमा': 86643,
#  '▁International': 22000,
#  '▁ხელმ': 152468,
#  '▁පවා': 232240,
#  '▁다가': 81890,
#  '你': 249188,
#  '▁عضو': 121775,
#  '▁उक्त': 82241,
#  '▁শর': 97361,
#  'ilja': 68527,
#  '▁Setaani': 191954,
#  'elekọta': 213300,
#  '▁tlhole': 135319,
#  '▁macco': 101735,
#  '▁tua': 3653,
#  'unpaman': 131425,
#  'rank': 72540,
#  'kmr_Latn': 256099,
#  '▁छेड़': 235531,
#  '▁kotambwisa': 205041,
#  '▁ræða': 191913,
#  '▁pwysig': 224475,
#  '▁Caleb': 177735,
#  '▁chat': 32779,
#  '▁nguyên': 43089,
#  '▁تجدید': 212593,
#  '▁kuvandaka': 58097,
#  '▁онла': 57238,
#  '▁lắm': 153169,
#  'శాల': 94543,
#  'verkar': 105922,
#  '▁jiselevende': 106093,
#  'dü': 31392,
#  'вно': 6409,
#  'ñana': 231905,
#  '▁cependant': 218710,
#  '▁બદલ': 134925,
#  'ayogikeun': 191200,
#  '▁2': 140,
#  '▁èrò': 83826,
#  '▁finansiële': 241444,
#  '▁అన్నారు': 102029,
#  '海の': 193083,
#  '▁That': 11582,
#  '▁ಸಾಮಾನ್ಯವಾಗಿ': 75642,
#  '▁Sind': 66566,
#  '▁prese': 71408,
#  '▁اڪ': 85326,
#  '▁bakoki': 66055,
#  '▁では': 31546,
#  '▁Или': 54760,
#  'фан': 101884,
#  '▁Direct': 96378,
#  'atane': 117632,
#  '▁실수를': 163961,
#  '▁қолдау': 99137,
#  'باس': 177610,
#  'wade': 184415,
#  '▁национа': 38751,
#  '▁във': 56746,
#  'amug': 244260,
#  'ibang': 140925,
#  '▁خشونت': 158372,
#  '▁ידעתי': 185269,
#  '基地': 128452,
#  'hannya': 59353,
#  '▁baja': 78374,
#  '▁सत्य': 42040,
#  '▁הדרך': 109696,
#  '▁lumière': 136402,
#  'jeneste': 146731,
#  'yorum': 9764,
#  'сним': 229740,
#  '▁spiritu': 50479,
#  '▁laela': 102076,
#  '▁Nasa': 87986,
#  '▁ኣይኮነን': 189074,
#  '▁tulen': 191069,
#  '▁grund': 14958,
#  '▁ïåð': 170962,
#  '▁ટેક્': 213541,
#  '▁باند': 168366,
#  '흙': 253485,
#  '▁manyan': 70361,
#  '្ង': 61012,
#  'hend': 11567,
#  'ƒetɔ': 55381,
#  'teerera': 243399,
#  '▁dɔɔni': 102198,
#  'Babe': 231201,
#  'CoV': 86932,
#  '말': 249070,
#  '▁médecin': 247561,
#  '▁markar': 54007,
#  'כשי': 29490,
#  'phumelela': 154561,
#  'vemento': 104870,
#  'emine': 125101,
#  '▁Соң': 157576,
#  'lasti': 15375,
#  '▁Mani': 47178,
#  'แก้': 153310,
#  '履行': 137661,
#  'dọ': 54190,
#  '▁etip': 165063,
#  'òla': 198631,
#  '▁שעות': 117880,
#  'কী': 35043,
#  'ssa': 153557,
#  '▁skydda': 227756,
#  '▁esquer': 159498,
#  'eser': 81807,
#  '▁маани': 102851,
#  ...}

# %%
thai_char_min = 0x0E00
thai_char_max = 0x0E7F

thai_tokens = [
    token for token in tokenizer.vocab.keys()
    if any(thai_char_min <= ord(char) <= thai_char_max for char in token)
]

thai_token_count = len(thai_tokens)
sample_size = 20
thai_tokens_sample = thai_tokens[:sample_size]


print(f"{thai_token_count}\n")
for token in thai_tokens_sample:
  print(token)
# Out:
# 1712
#
# ▁เพราะว่า
# ช่วง
# ไหร
# มาก่อน
# ▁ฉันรู้ว่า
# ถ้า
# ▁ไ
# ือบ
# อม
# ยังไม่
# ๋
# เลข
# โรค
# ไปได้
# อยู่ใน
# คิดถึง
# ็ง
# ฏ
# ของเขา
# ▁ท

# %%
import tensorflow as tf
import plotly.graph_objects as go
import plotly.express as px
from plotly.subplots import make_subplots
import numpy as np
import math

# %%
sentence = 'Work hard, play harder'

# %%
cleaned_sentence = sentence.replace(',', '')
cleaned_sentence
# Out:
# 'Work hard play harder'

# %%
words = cleaned_sentence.split()
words
# Out:
# ['Work', 'hard', 'play', 'harder']

# %%
sorted_words = sorted(words)
sorted_words
# Out:
# ['Work', 'hard', 'harder', 'play']

# %%
dc = {word: index for index, word in enumerate(sorted_words)}
dc
# Out:
# {'Work': 0, 'hard': 1, 'harder': 2, 'play': 3}

# %%
sentence_int = tf.constant(
    [dc[s] for s in sentence.replace(',', '').split()],
    dtype=tf.int32
)

# %%
print(sentence)
print(sentence_int)
# Out:
# Work hard, play harder
# tf.Tensor([0 1 3 2], shape=(4,), dtype=int32)

# %%
# สร้าง embedding layer
tf.random.set_seed(123)
vocab_size = 50_000
embedding_dim = 2

embed = tf.keras.layers.Embedding(input_dim=vocab_size, output_dim=embedding_dim)

# %%
embedded_sentence = embed(sentence_int)

# %%
embedded_sentence
# Out:
# <tf.Tensor: shape=(4, 2), dtype=float32, numpy=
# array([[ 0.02237128,  0.00224324],
#        [-0.01629701,  0.03979938],
#        [ 0.02920152, -0.0307174 ],
#        [ 0.01230965,  0.03437949]], dtype=float32)>

# %%
tf.random.set_seed(123)
vocab_size = 50_000
embedding_dim = 2

dummy_input = tf.constant([0, 1, 2], dtype=tf.int32)

# Case 1 Default initializer (RandomUniform(-0.05, 0.05))
embed_default = tf.keras.layers.Embedding(input_dim=vocab_size, output_dim=embedding_dim)
_ = embed_default(dummy_input) # เรียกใช้งาน layer เพื่อสร้าง weights
weights_default = embed_default.get_weights()[0].flatten()
weights_default.shape
# Out:
# (100000,)

# %%
# Case 2 GlorotUniform initializer
tf.random.set_seed(123)
embed_glorot = tf.keras.layers.Embedding(
    input_dim=vocab_size,
    output_dim=embedding_dim,
    embeddings_initializer=tf.keras.initializers.GlorotUniform()
)
_ = embed_glorot(dummy_input) # เรียกใช้งาน layer เพื่อสร้าง weights
weights_glorot = embed_glorot.get_weights()[0].flatten()
weights_glorot.shape
# Out:
# (100000,)

# %%
fig = make_subplots(rows=1, cols=1)

fig.add_trace(go.Histogram(x=weights_default, nbinsx=50, name="Default Uniform [-0.05, 0.05]", opacity=0.6))
fig.add_trace(go.Histogram(x=weights_glorot, nbinsx=50, name="Glorot Uniform", opacity=0.6))

fig.update_layout(
    title_text='Embedding Layer Initialization Comparison',
    xaxis_title_text='Weight values',
    yaxis_title_text='Frequency',
    barmode='overlay',
    legend_orientation="h",
    legend_yanchor="bottom",
    legend_y=1.02,
    legend_xanchor="right",
    legend_x=1
)

fig.show()

print("Default initializer range ", weights_default.min(), weights_default.max())
print("Glorot initializer range ", weights_glorot.min(), weights_glorot.max())
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="02c566b4-7efb-42a4-bd0d-fdf7de039927" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("02c566b4-7efb-42a4-bd0d-fdf7de039927")) {                    Plotly.newPlot(                        "02c566b4-7efb-42a4-bd0d-fdf7de039927",                        [{"name":"Default Uniform [-0.05, 0.05]","nbinsx":50,"opacity":0.6,"x":[-0.0153950825,0.040258553,-0.048963297,0.04413232,0.020957757,-0.030293275,0.041899506,-0.038089156,0.0014714114,0.045319807,0.019323472,-0.04480542,-0.03668531,-0.049280465,-0.03314378,-0.04718963,0.0026974455,0.039315198,-0.01157267,0.048546825,-0.03239453,-0.0045664087,0.026702236,-0.03018229,-0.032848135,0.044430915,0.013653729,0.04809243,0.040793072,-0.005007576,-0.03784164,-0.035551883,0.034059215,-0.012438498,0.03907195,0.038790654,0.036252324,0.006941758,0.04414176,-0.047679435,0.04093683,-0.010773946,0.04108328,-0.026770234,0.04086894,-0.032003034,0.021702874,-0.03834703,0.01921587,-0.043384638,0.018606331,0.011025239,0.005281877,0.020864878,0.03595381,-0.01499648,0.04394083,-0.004714884,0.038031388,-0.03182715,0.04177877,-0.018605866,0.02157661,0.00501398,-0.037628733,-0.022982169,-0.011621021,-0.004391633,0.025073972,-0.018410385,0.013974611,-0.011251271,-0.04948565,-0.04945307,0.015477251,0.017603766,0.044354204,0.0048970804,-0.049751293,-0.03203938,-0.025538648,-0.022120869,-0.03671081,-0.032151118,-0.0033490174,0.043629956,0.04524709,-0.030885769,0.0044387095,0.04315075,0.047664773,0.01553512,-0.023279775,0.04433323,-0.00877291,0.028729942,-0.00828924,-0.036457647,-0.011449598,0.0025414936,0.0058231466,0.021592174,-0.0089474805,0.017418686,-0.0027949214,0.0033120997,0.0014689788,0.00045915693,0.044500913,0.030643832,0.044806268,0.010117374,0.01329967,-0.03219402,0.028592993,0.020245615,-0.0494941,0.034668114,-0.024587547,0.006361712,-0.0049238913,0.01224196,-0.024652554,0.024616312,-0.017397571,-0.043024924,0.04971203,0.028007556,-0.007173322,0.026251052,0.043030683,0.0056425445,0.045154188,-0.02705741,0.034933005,0.045782294,-0.039397858,0.038899865,-0.0081231,-0.03205104,0.002455879,-0.017563961,0.02258965,0.015441764,-0.000972189,-0.010252725,-0.006905604,0.02836876,-0.036090694,0.043649245,-0.011782169,0.023548435,-0.001176022,-0.047673058,-0.031121088,-0.043637313,0.038138937,0.020811629,0.026094291,-0.00073337555,0.007494103,-0.036178123,-0.0033090934,0.041019585,-0.047281373,-0.01781999,-0.019583989,-0.0061572082,-0.019121146,0.029564884,0.03689548,-0.039329804,-0.0021408685,-0.02441739,-0.030078888,-0.049747195,0.017772745,-0.030741466,-0.019852364,-0.020789325,0.040533032,0.020095874,-0.04598489,0.014701273,-0.03846406,-0.023800313,-0.0074903257,-0.008530535,-0.022642434,-0.028010821,0.014077965,-0.040679455,0.046558704,0.013393413,0.01297548,0.018095206,-0.01034566,-0.039210998,-0.044143356,-0.01799357,0.04996622,0.015809681,0.013308551,-0.01144167,0.038049076,-0.0345755,0.04545187,-0.017002214,0.03686771,0.049373854,0.00070454925,-0.043903958,0.00070206076,0.047631968,0.014071491,-0.021221472,0.0037727952,0.013883833,0.032208893,-0.0118447915,-0.041903816,-0.0064541586,-0.03515581,-0.032272972,0.013464633,-0.017128088,-0.0018847361,0.028067235,-0.020378841,-0.0002278462,-0.036732912,-0.04753189,0.033451747,0.0040503256,0.026286233,-0.015252136,0.015255455,-0.0016845576,-0.03762244,-0.030918956,-0.02367344,-0.01667739,0.036550645,-0.019836772,0.013903808,0.016467545,0.024588358,-0.01632186,0.011105977,0.006188702,-0.048233785,-0.04776149,0.04870567,0.005532898,-0.009381354,0.011384405,0.0033582225,-0.0224234,0.025897373,0.010307837,-0.013316296,-0.019790566,-0.04684756,0.000104714185,0.02119689,-0.006506406,0.035500813,0.029229749,0.008512188,-0.041904222,0.007547904,-0.03328897,0 ...
# Default initializer range  -0.049999487 0.04999921
# Glorot initializer range  -0.010954115 0.010953954

# %%
def glorot_uniform_limits(fan_in, fan_out):
    limit = math.sqrt(6.0 / (fan_in + fan_out))
    a, b = -limit, limit
    return a, b

# ตัวอย่าง Embedding layer (vocab_size=50000, embedding_dim=2)
fan_in = 50000
fan_out = 2

a, b = glorot_uniform_limits(fan_in, fan_out)
print("Glorot Uniform a =", a)
print("Glorot Uniform b =", b)
# Out:
# Glorot Uniform a = -0.010954232067652772
# Glorot Uniform b = 0.010954232067652772

# %%
model = AutoModelForSeq2SeqLM.from_pretrained(checkpoint)
# Out:
# config.json:   0%|          | 0.00/846 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/2.46G [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.46G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/189 [00:00<?, ?B/s]

# %%
token_embedding_layer = model.model.encoder.embed_tokens
token_embedding_layer.weight.shape
# Out:
# torch.Size([256206, 1024])

# %%
long_sentence = "In the vast realm of natural language processing, understanding the nuances of how models handle sequential data is crucial. Positional encoding plays a vital role in providing this essential information to the model, allowing it to differentiate between words at different positions in a sentence, which is fundamental for tasks like translation, summarization, and text generation."

# %%
tokens = tokenizer(long_sentence, return_tensors="pt")

print(tokens['input_ids'][0])
# Out:
# tensor([256047,    717,    349,  14430,  12284, 248070,    452,  25307,  65445,
#         157278, 248079, 133930,    349,    713,  75831,    452,  11657, 141057,
#          47274, 116914, 124785,   6067,    248, 182071, 248075,  12013,  58409,
#          12025, 246156,   3054,    705,      9, 104781,  76065,    108, 174693,
#           3423, 140515,  18781,    202,    349,  14916, 248079,  82935,     87,
#            796,    202,  53054,    502,  25914,  51744,    230,  30158, 199073,
#            108,      9, 109267, 248079,   9089,    248,  75529,    351, 226047,
#           6399, 200356, 248079,   2493, 109207, 181953, 248079,    540,  35883,
#         120531, 248075,      2])

# %%
len(tokens['input_ids'][0])
# Out:
# 75

# %%
token_embedding_layer(tokens['input_ids'][0][0]).shape
# Out:
# torch.Size([1024])

# %%
token_embeddings = token_embedding_layer(tokens['input_ids'][0])

print("Token Embedding Matrix shape", token_embeddings.shape)
token_embeddings
# Out:
# Token Embedding Matrix shape torch.Size([75, 1024])
# tensor([[-5.0000e+00, -1.2725e+00, -9.3604e-01,  ..., -1.8297e+01,
#          -9.1328e+00, -1.0672e+01],
#         [ 2.6416e-01,  2.6831e-01,  2.0117e-01,  ...,  3.2715e+00,
#          -3.2402e+00,  3.1738e+00],
#         [ 4.3579e-01, -2.3352e-01,  2.6825e-02,  ...,  5.4648e+00,
#           2.7129e+00,  5.5430e+00],
#         ...,
#         [ 8.5859e+00, -4.5391e+00, -4.7314e-01,  ..., -7.9529e-02,
#           7.4844e+00, -7.5156e+00],
#         [-2.4863e+00, -2.7515e-01,  5.6114e-03,  ...,  1.0180e+01,
#          -7.2422e+00, -4.8047e+00],
#         [-7.8320e-01, -9.0527e-01, -9.4482e-01,  ...,  3.1078e+01,
#          -8.1494e-01, -8.7354e-01]], grad_fn=<MulBackward0>)

# %%
import plotly.express as px

token_embeddings_np = token_embeddings.detach().numpy()

fig = px.imshow(
    token_embeddings_np,
    color_continuous_scale="RdBu",
    labels=dict(x="Embedding Dimension", y="Token Index", color="Value"),
    title="Token Embedding Heatmap"
)

fig.update_xaxes(side="top")
fig.update_layout(height=500, width=900)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="6e79d3f9-2105-4320-abf5-fdb818e35398" class="plotly-graph-div" style="height:500px; width:900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6e79d3f9-2105-4320-abf5-fdb818e35398")) {                    Plotly.newPlot(                        "6e79d3f9-2105-4320-abf5-fdb818e35398",                        [{"coloraxis":"coloraxis","name":"0","z":[[-5.0,-1.2724609,-0.93603516,-0.83203125,-2.8164062,-1.4824219,-1.4541016,-1.5322266,-2.0976562,-1.3632812,-1.3916016,-0.8466797,-0.40673828,-2.1171875,-2.9785156,-5.9257812,-3.2480469,-3.2265625,-5.4296875,-4.6445312,-4.6210938,-2.7578125,1.6699219,0.23669434,2.6699219,0.6894531,2.1640625,-1.4003906,-1.5332031,1.078125,0.27319336,-0.044677734,-4.484375,2.7148438,-0.82714844,-0.9248047,-1.4833984,1.5966797,0.3942871,2.7675781,-0.18151855,-1.4208984,1.4765625,-3.5234375,-1.9033203,-0.36523438,-3.0449219,-7.0078125,3.3378906,-2.4453125,-1.21875,0.6464844,-0.20788574,0.50927734,-0.35546875,2.6171875,-1.484375,-7.21875,-1.6210938,-4.1679688,-6.3476562,0.6245117,-0.8540039,-0.36621094,0.53759766,-4.03125,-1.4160156,-1.6035156,-0.20056152,-2.6367188,0.5800781,-4.2421875,-1.0517578,1.6572266,-3.7011719,-2.1425781,-2.3203125,-0.46142578,-3.1484375,-3.5039062,5.1484375,1.5410156,-2.4667969,1.8359375,-0.8930664,1.2636719,-2.5976562,1.8720703,-1.9160156,1.6894531,-0.9248047,-3.6503906,-2.6464844,3.9433594,-1.8027344,0.08276367,-2.3632812,-0.3720703,-1.2607422,-1.0986328,0.82666016,-2.9101562,-0.7949219,3.4023438,3.4804688,-5.0664062,1.2001953,-2.8222656,-0.0925293,-0.06573486,-4.15625,-0.24804688,-5.2421875,-5.2070312,-1.1210938,-2.1269531,-0.9296875,1.3291016,0.5756836,3.2910156,0.028930664,-3.2949219,-0.74902344,1.9746094,3.2324219,-2.9824219,-4.078125,2.9355469,-0.37890625,-6.0429688,-1.1982422,5.2929688,-0.9555664,-1.0087891,-2.4609375,-2.8320312,7.0390625,1.34375,6.0195312,-4.3007812,-0.33691406,1.3554688,1.9746094,0.88964844,-0.8432617,-1.1689453,2.0429688,-3.375,-2.2167969,-1.0732422,-6.8984375,5.59375,0.70751953,-2.4511719,1.0996094,2.953125,1.5742188,0.7495117,-4.53125,-2.7207031,2.3007812,0.19958496,1.5048828,-2.625,4.9140625,1.2363281,-1.4033203,-0.7739258,2.9023438,-1.9794922,0.5097656,-5.03125,4.3164062,-1.4628906,-3.6289062,7.9023438,-5.4101562,-0.79541016,1.2724609,-3.03125,-3.2617188,-0.7285156,9.453125,6.8710938,-0.78027344,0.8461914,-0.028656006,-1.4453125,-0.89697266,0.20361328,-5.5234375,-3.1992188,0.09460449,5.4921875,-2.9335938,5.6484375,0.92285156,2.1542969,-3.6738281,-2.5722656,-5.1953125,-4.4296875,6.0625,2.1171875,-0.19140625,2.3886719,-2.3144531,-1.4082031,1.1728516,9.0859375,-5.3789062,-0.14526367,-3.1972656,1.8076172,0.8041992,2.4199219,-0.009849548,-6.2070312,-1.6171875,-3.8027344,2.0898438,-2.5351562,0.86816406,0.17224121,-0.5800781,3.7070312,1.9980469,5.015625,-1.7001953,-0.2734375,-1.4921875,3.2675781,-1.4570312,-3.8964844,-1.7021484,-5.0351562,2.5410156,-4.4414062,-2.9394531,9.359375,-0.703125,-0.5439453,-11.515625,4.1367188,6.640625,2.7636719,-2.6054688,-0.5625,1.6259766,0.94140625,0.2746582,0.24401855,-5.3671875,4.6367188,-5.25,6.1484375,-5.5429688,-0.3149414,-2.1875,-2.0859375,-1.1806641,7.3671875,-0.17993164,-1.1494141,-15.9296875,-1.5449219,-3.7226562,-4.6484375,3.0507812,5.1835938,-2.4550781,3.71875,-0.9057617,8.40625,0.1361084,-4.65625,3.203125,0.28466797,-7.28125,-2.9941406,-5.0625,0.92578125,-12.6796875,-5.2929688,0.47802734,18.0625,-11.078125,3.34375,-3.3222656,0.3605957,-6.3164062,-17.1875,3.6796875,-4.4257812,-8.4375,-6.2578125,16.046875,-4.4570312,0.10467529,0.18127441,-4.0664062,-0.4375,1.3125,-1.5859375,-3.6503906,-5.1875,0.32910156,-3.6367188,-3.1835938,-1.5380859,-2.1601562,2.2910156,2.0507812,4.1367188,3.1503906,-0.33325195,-0.03668213,0.8671875,-2.8515625,-7.3359375,-2.9296875,-4.6015625,0.0 ...

# %%
d = embedded_sentence.shape[-1]
d
# Out:
# 2

# %%
d_q, d_k, d_v = 2, 2, 4

d_q, d_k, d_v
# Out:
# (2, 2, 4)

# %%
tf.random.set_seed(123)
W_query = tf.Variable(tf.random.uniform((d, d_q)), trainable=True)
W_key   = tf.Variable(tf.random.uniform((d, d_k)), trainable=True)
W_value = tf.Variable(tf.random.uniform((d, d_v)), trainable=True)

# %%
print(W_query.shape, W_key.shape, W_value.shape)
# Out:
# (2, 2) (2, 2) (2, 4)

# %%
W_query
# Out:
# <tf.Variable 'Variable:0' shape=(2, 2) dtype=float32, numpy=
# array([[0.12615311, 0.5727513 ],
#        [0.2993133 , 0.5461836 ]], dtype=float32)>

# %%
W_key
# Out:
# <tf.Variable 'Variable:0' shape=(2, 2) dtype=float32, numpy=
# array([[0.88968754, 0.12354946],
#        [0.7718717 , 0.6850728 ]], dtype=float32)>

# %%
W_value
# Out:
# <tf.Variable 'Variable:0' shape=(2, 4) dtype=float32, numpy=
# array([[0.48962688, 0.5857923 , 0.36451697, 0.6550509 ],
#        [0.9075084 , 0.37557673, 0.6882372 , 0.25384045]], dtype=float32)>

# %%
embedded_sentence
# Out:
# <tf.Tensor: shape=(4, 2), dtype=float32, numpy=
# array([[ 0.02237128,  0.00224324],
#        [-0.01629701,  0.03979938],
#        [ 0.02920152, -0.0307174 ],
#        [ 0.01230965,  0.03437949]], dtype=float32)>

# %%
queries = tf.matmul(embedded_sentence, W_query)
keys    = tf.matmul(embedded_sentence, W_key)
values  = tf.matmul(embedded_sentence, W_value)

# %%
print("Queries shape", queries.shape)
queries
# Out:
# Queries shape (4, 2)
# <tf.Tensor: shape=(4, 2), dtype=float32, numpy=
# array([[ 3.4936392e-03,  1.4038403e-02],
#        [ 9.8565668e-03,  1.2403639e-02],
#        [-5.5102631e-03, -5.2131712e-05],
#        [ 1.1843140e-02,  2.5827883e-02]], dtype=float32)>

# %%
print("Keys shape", keys.shape)
keys
# Out:
# Keys shape (4, 2)
# <tf.Tensor: shape=(4, 2), dtype=float32, numpy=
# array([[ 0.02163495,  0.00430074],
#        [ 0.01622077,  0.02525199],
#        [ 0.00227034, -0.01743582],
#        [ 0.0374883 ,  0.0250733 ]], dtype=float32)>

# %%
print("Values shape", values.shape)
values
# Out:
# Values shape (4, 4)
# <tf.Tensor: shape=(4, 4), dtype=float32, numpy=
# array([[ 0.01298934,  0.01394743,  0.00969859,  0.01522375],
#        [ 0.02813882,  0.00540106,  0.02145088, -0.00057267],
#        [-0.01357845,  0.00556928, -0.01049641,  0.01133116],
#        [ 0.03722681,  0.02012303,  0.02814832,  0.01679035]],
#       dtype=float32)>

# %%
omega = tf.matmul(queries, keys, transpose_b=True)

print("Omega shape", omega.shape)
print("Omega (Unnormalized attention weights)")
print(omega)
# Out:
# Omega shape (4, 4)
# Omega (Unnormalized attention weights)
# tf.Tensor(
# [[ 1.3596028e-04  4.1116707e-04 -2.3683933e-04  4.8295973e-04]
#  [ 2.6659117e-04  4.7309767e-04 -1.9388989e-04  6.8050611e-04]
#  [-1.1943845e-04 -9.0697169e-05 -1.1601196e-05 -2.0787749e-04]
#  [ 3.6730483e-04  8.4431027e-04 -4.2344243e-04  1.0915695e-03]], shape=(4, 4), dtype=float32)

# %%
d_k = tf.cast(d_k, tf.float32)

scaled_omega = omega / tf.sqrt(d_k)

attention_weights = tf.nn.softmax(scaled_omega, axis=-1)

print("Attention Weights")
print(attention_weights)
# Out:
# Attention Weights
# tf.Tensor(
# [[0.24998897 0.2500376  0.24992308 0.2500503 ]
#  [0.24999292 0.2500294  0.24991152 0.2500661 ]
#  [0.24999787 0.25000295 0.25001693 0.24998224]
#  [0.24998185 0.25006616 0.2498421  0.2501099 ]], shape=(4, 4), dtype=float32)

# %%
row_sums = tf.reduce_sum(attention_weights, axis=-1)

print("Sum of each row in attention_weights")
row_sums
# Out:
# Sum of each row in attention_weights
# <tf.Tensor: shape=(4,), dtype=float32, numpy=array([1., 1., 1., 1.], dtype=float32)>

# %%
context_vector = tf.matmul(attention_weights, values)

print("Context Vector shape", context_vector.shape)
print(context_vector)
# Out:
# Context Vector shape (4, 4)
# tf.Tensor(
# [[0.01619796 0.01126084 0.01220327 0.01069293]
#  [0.01619853 0.0112611  0.0122037  0.01069313]
#  [0.0161933  0.01125993 0.01219971 0.01069301]
#  [0.01620199 0.01126164 0.01220634 0.01069289]], shape=(4, 4), dtype=float32)

# %%
class SelfAttention(tf.keras.layers.Layer):
    def __init__(self, d_in, d_out_kq, d_out_v):
        super().__init__()
        self.d_out_kq = d_out_kq

        self.W_query = tf.Variable(
            tf.random.uniform((d_in, d_out_kq)), trainable=True
        )
        self.W_key = tf.Variable(
            tf.random.uniform((d_in, d_out_kq)), trainable=True
        )
        self.W_value = tf.Variable(
            tf.random.uniform((d_in, d_out_v)), trainable=True
        )

    def call(self, x):
        keys = tf.matmul(x, self.W_key)      # [T, d_out_kq]
        queries = tf.matmul(x, self.W_query) # [T, d_out_kq]
        values = tf.matmul(x, self.W_value)  # [T, d_out_v]

        # Attention scores: QKᵀ
        attn_scores = tf.matmul(queries, keys, transpose_b=True)  # [T, T]

        # Softmax (scaled by sqrt(d_k))
        attn_weights = tf.nn.softmax(
            attn_scores / tf.math.sqrt(tf.cast(self.d_out_kq, tf.float32)), axis=-1
        )  # [T, T]

        # Weighted sum
        context_vec = tf.matmul(attn_weights, values)  # [T, d_out_v]
        return context_vec

# %%
tf.random.set_seed(123)

d_in, d_out_kq, d_out_v = 2, 2, 4

sa = SelfAttention(d_in, d_out_kq, d_out_v)

out = sa(embedded_sentence)

print(out.shape)  # (T, d_out_v)
print(out.numpy())
# Out:
# (4, 4)
# [[0.01619796 0.01126084 0.01220327 0.01069293]
#  [0.01619853 0.0112611  0.0122037  0.01069313]
#  [0.0161933  0.01125993 0.01219971 0.01069301]
#  [0.01620199 0.01126164 0.01220634 0.01069289]]

# %%
class MultiHeadAttentionWrapper(tf.keras.layers.Layer):
    def __init__(self, d_in, d_out_kq, d_out_v, num_heads):
        super().__init__()
        self.heads = [
            SelfAttention(d_in, d_out_kq, d_out_v)
            for _ in range(num_heads)
        ]

    def call(self, x):
        # รันทุก head แล้ว concat ตามแกนสุดท้าย
        head_outputs = [head(x) for head in self.heads]   # list of [T, d_out_v]
        return tf.concat(head_outputs, axis=-1)           # [T, num_heads * d_out_v]

# %%
tf.random.set_seed(123)

d_in, d_out_kq, d_out_v = 2, 2, 1

sa = SelfAttention(d_in, d_out_kq, d_out_v)

# ถ้า embedded_sentence.shape = [T, d_in] เช่น [6, 3]
out = sa(embedded_sentence)

print(out.shape)   # (T, d_out_v) -> (6, 1)
print(out.numpy())
# Out:
# (4, 1)
# [[0.01252019]
#  [0.01252057]
#  [0.01251764]
#  [0.0125224 ]]

# %%
tf.random.set_seed(123)

block_size = embedded_sentence.shape[0]   # [T, d_in] → T = sequence length

mha = MultiHeadAttentionWrapper(
    d_in, d_out_kq, d_out_v, num_heads=3
)

# run MHA
context_vecs = mha(embedded_sentence)   # [T, num_heads * d_out_v]

print(context_vecs)
print("context_vecs.shape:", context_vecs.shape)
# Out:
# tf.Tensor(
# [[0.01252019 0.01514383 0.01926827]
#  [0.01252057 0.01514413 0.01926409]
#  [0.01251764 0.01514516 0.01926812]
#  [0.0125224  0.01514274 0.01926794]], shape=(4, 3), dtype=float32)
# context_vecs.shape: (4, 3)
